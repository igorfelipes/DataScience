# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# %%
gender_development_df = pd.read_csv('gender_development_index.csv')
gender_inequality_index  = pd.read_csv('gender_inequality_index.csv')

# %%
gender_development_df = gender_development_df.dropna(axis=1, how='all').set_index('Country')

# %%
gender_development_df.drop('HDI Rank (2015)', inplace=True, axis=1)

# %%
gender_development_df['mean'] = gender_development_df.mean(axis=1)

# %%
gender_development_df['std'] = gender_development_df.std(axis=1)

# %%
gender_development_df['max'] = gender_development_df.max(axis=1)

# %%
gender_development_df['min'] = gender_development_df.min(axis=1)

# %%
gender_development_df
# Out:
#                                       2000   2005   2010   2011   2012   2013  \
# Country
#  Afghanistan                         0.282  0.481  0.580  0.594  0.602  0.607
#  Albania                             0.936  0.944  0.959  0.957  0.960  0.960
#  Algeria                             0.788  0.815  0.845  0.845  0.845  0.847
#  Argentina                           0.981  1.001  0.998  0.987  0.989  0.989
#  Armenia                             0.947  0.976  1.002  1.003  1.000  0.998
# ...                                    ...    ...    ...    ...    ...    ...
#  Venezuela (Bolivarian Republic of)  0.987  1.011  1.028  1.028  1.029  1.029
#  Viet Nam                            0.958  0.985  0.992  0.996  1.002  1.006
#  Yemen                               0.646  0.698  0.736  0.738  0.740  0.748
#  Zambia                                NaN    NaN  0.898  0.905  0.911  0.916
#  Zimbabwe                            0.825  0.839  0.898  0.908  0.916  0.921
#
# ...
